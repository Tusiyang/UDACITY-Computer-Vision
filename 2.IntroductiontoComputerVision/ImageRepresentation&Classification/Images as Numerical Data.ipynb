# %% [markdown]
# # Images as Grids of Pixels

# %% [markdown]
# ### Import resources

# %%
import numpy as np
import matplotlib.image as mpimg  # for reading in images

import matplotlib.pyplot as plt
import cv2  # computer vision library

# %matplotlib inline

# %% [markdown]
# ### Read in and display the image

# %%
# Read in the image
image= mpimg.imread("images/waymo_car.jpg")

# Print out the image dimensions
print("Image dimentions:", image.shape)

# Change from color to grayscale
gray_image= cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)

plt.imshow(gray_image, cmap='gray')
# Out:
# Image dimentions: (427, 640, 3)

# %%
# Prints specific grayscale pixel values
# What is the pixel value at x = 400 and y = 300 (on the body of the car)?

x = 400
y = 300

print(gray_image[y,x])
# Out:
# 159

# %%
# Finds the maximum and minimum grayscale values in this image

max_val = np.amax(gray_image) # the a in amax means array
min_val = np.amin(gray_image)

print('Max: ', max_val)
print('Min: ', min_val)
# Out:
# Max:  255
# Min:  2

# %%
# Create a 5x5 image using just grayscale, numerical values
tiny_image = np.array([[150, 150,150, 150, 150],
                      [150, 0, 150, 0, 150],
                      [150, 150, 150, 150, 150],
                      [150, 0, 150, 0, 150],
                      [150, 0, 0, 0, 150]])

# To show the pixel grid, use matshow
plt.matshow(tiny_image, cmap='gray') # the mat in matshow means matrix

## TODO: See if you can draw a tiny smiley face or something else!
## You can change the values in the array above to do this

# %% [markdown]
# ### The following is one possible solution
# tiny_smile = np.array([[150, 150,150, 150, 150],
#                       [150, 0, 150, 0, 150],
#                       [150, 150, 150, 150, 150],
#                       [150, 0, 150, 0, 150],
#                       [150, 0, 0, 0, 150]])
#
# ### To show the pixel grid, use matshow
# plt.matshow(tiny_smile, cmap='gray')
